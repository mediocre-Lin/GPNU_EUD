# %% [markdown]
# <h1 align="center">GPNU_EUD</h1>
# <div style="color:#FFFDB1;
#             background-color:#87B9FF;
#             margin-left: 4in ;
#             margin-right: 4in ;
#             margin-top: 0.5in;">
#     <h2 align="center">Eat Up Data 吃掉数据</h2>
# </div>
#
# <div align="right"></div>
#
# # python

# %% [markdown]
# ### Python 环境和IDE选择
#
# - 推荐Anaconda： 便于安装各种库,并且自带Jupyter notebook，是一个交互式笔记本，便于创建和共享文学化程序文档，支持实时代码，数学方程，可视化和 markdown。安装完建议首先更换镜像源（百度有教程，因为默认国外的镜像源，网络可能不太允许）
#
#
#
# - Pycharm、VScode : 适合工程项目，例如后期的深度学习

# %% [markdown]
# ## Python 基础
#
#
# 第一个月冲冲冲！！！
#
#
# **学习内容**：
#
# 主要以泰迪学社Python快速入门(https://edu.tipdm.org/my/course/7) 的内容作为学习的python一个简要流程，相关的内容补充可以参考
#
# 《Head+First+Python》 、 莫烦 Python 教程(https://www.bilibili.com/video/BV1wW411Y7ai?from=search&seid=16430166932121889693)
#
#
#
#
#
#
#
#
#
#  1. python 基础一：
#      - 目标 ： 学习基础条件语句和基础的数据类型和数据结构（列表、字典、集合）
#      - 时间周期 ：7天
# ![p1.png](attachment:p1.png)
#
#
#
#
# <br><br>
#  2. python 基础一：
#      - 目标 ： 学习基本的文件操作、自定义函数、面向对象、魔法方法
#      - 时间周期 ：7天
# ![p2.jpg](attachment:p2.jpg)

# %% [markdown]
# ## Numpy 、 Pandas 、Matplotlib
#
# **学习内容**：Numpy、Pandas、Matplotlib是数据科学的基础必备的库，也是必须掌握的。我们主要使用《利用python进行数据分析》一书作为教材
#
#
#  1. Numpy 、 Pandas 基础一：
#      - 目标 ： 学习基础Numpy 、 Pandas，掌握基础的array和Series、DataFrame数据结构
#      - 时间周期 ：7天

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Numpy 、 Pandas 进阶和Matplotlib绘图：
#      - 目标 ： 学习Numpy 、 Pandas的进阶功能和Matplotlib绘图库进行数据的可视化
#      - 时间周期 ：7天

# %% [markdown]
# ![image.png](attachment:image.png)
